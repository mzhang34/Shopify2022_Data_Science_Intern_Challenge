# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('winter_data_challenge.xlsx')
print (df)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at
# 0    2017-03-13 12:36:56.190
# ...

# %%
df.head() #checking the first few rows
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#                created_at
# 0 2017-03-13 12:36:56.190
# 1 2017-03-03 17:38:51.999
# 2 2017-03-14 04:23:55.595
# 3 2017-03-26 12:43:36.649
# 4 2017-03-01 04:35:10.773

# %%
df.isnull().sum() #checking if there is any null value
# Out:
# order_id          0
# shop_id           0
# user_id           0
# order_amount      0
# total_items       0
# payment_method    0
# created_at        0
# dtype: int64

# %%
df.duplicated() #checking duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %%
df['shop_id'].nunique()
# Out:
# 100

# %%
df['shop_id'].value_counts()
# Out:
# 53    68
# 71    66
# 19    64
# 13    63
# 89    61
#       ..
# 74    38
# 56    37
# 67    37
# 38    35
# 85    35
# Name: shop_id, Length: 100, dtype: int64

# %%
df_user_orders = pd.DataFrame({'average_order_value': df.groupby('user_id')['order_amount'].mean().sort_values(ascending=False)})

# %%
df_user_orders
# Out:
#          average_order_value
# user_id
# 607            704000.000000
# 878             14266.909091
# 766              8007.600000
# 834              6019.000000
# 915              5785.142857
# ...                      ...
# 892               227.307692
# 899               226.666667
# 827               226.500000
# 939               219.600000
# 864               209.157895
#
# [301 rows x 1 columns]

# %%
df[df['user_id']==607] #evaluating the user who has an extremely high average order value
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
df[df['user_id']==892] #pick a random user that has average order values around the median
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 251        252       75      892           256            2          debit
# 338        339       52      892           146            1          debit
# 469        470       23      892           156            1          debit
# 1523      1524       96      892           306            2           cash
# 1989      1990       39      892           134            1           cash
# 2016      2017       57      892           147            1          debit
# 2044      2045       56      892           234            2          debit
# 2188      2189       30      892           153            1           cash
# 3484      3485       87      892           149            1           cash
# 3746      3747       29      892           326            2    credit_card
# 4310      4311       30      892           459            3          debit
# ...

# %%
subset_df = df[df['user_id']!=607]

# %%
subset_df.describe() #the AOV has decreased but still high comparing with median
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  4983.000000  4983.000000  4983.000000    4983.000000   4983.00000
# mean   2501.060405    50.106362   849.918322     754.091913      1.99398
# std    1443.090253    29.051718    86.800308    5314.092293      0.98318
# min       1.000000     1.000000   700.000000      90.000000      1.00000
# 25%    1250.500000    24.000000   776.000000     163.000000      1.00000
# 50%    2502.000000    50.000000   850.000000     284.000000      2.00000
# 75%    3750.500000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  154350.000000      8.00000

# %%
df[df['user_id']==878] #continue the analysis with next high average order value user
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 691        692       78      878        154350            6          debit
# 818        819       60      878           354            2          debit
# 927        928        2      878            94            1    credit_card
# 1575      1576       47      878           290            2           cash
# 1833      1834       74      878           153            1    credit_card
# 2011      2012       87      878           298            2           cash
# 3474      3475       20      878           254            2           cash
# 3647      3648       98      878           266            2           cash
# 4106      4107       26      878           176            1          debit
# 4215      4216       80      878           435            3          debit
# 4670      4671       98      878           266            2          debit
#
#                   created_at
# 691  2017-03-27 22:51:43.203
# ...

# %%
df[df['user_id']==766]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 1132      1133       81      766           354            2           cash
# 1278      1279       70      766           346            2    credit_card
# 1464      1465        4      766           128            1          debit
# 1691      1692       84      766           459            3          debit
# 2115      2116       63      766           544            4          debit
# 2169      2170        4      766           256            2          debit
# 2936      2937       69      766           262            2           cash
# 3422      3423       20      766           381            3           cash
# 3724      3725       78      766         77175            3    credit_card
# 3977      3978       55      766           171            1          debit
#
#                   created_at
# 1132 2017-03-07 15:43:40.091
# 1278 2017-03-15 20:05:21.677
# 1464 2017-03-22 23:36:52.580
# ...

# %%
df_shop_AOV = pd.DataFrame({'average_order_value': df.groupby('shop_id')['order_amount'].mean().sort_values(ascending=False)})

# %%
df_shop_AOV.plot.bar(figsize=(20,10)) #Inspecting shops that have high AOV
# Out:
# <AxesSubplot:xlabel='shop_id'>

# %%
df[df['shop_id']==42]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 40          41       42      793           352            1    credit_card
# 60          61       42      607        704000         2000    credit_card
# 308        309       42      770           352            1    credit_card
# 409        410       42      904           704            2    credit_card
# 520        521       42      607        704000         2000    credit_card
# 834        835       42      792           352            1           cash
# 835        836       42      819           704            2           cash
# 938        939       42      808          1056            3    credit_card
# 979        980       42      744           352            1          debit
# 1104      1105       42      607        704000         2000    credit_card
# ...

# %%
df[df['shop_id']==78] #shop 78 seem to not be a sneaker shop that is priced similarly with rest of the stores
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 691        692       78      878        154350            6          debit
# 1056      1057       78      800         25725            1          debit
# 1193      1194       78      944         25725            1          debit
# 1204      1205       78      970         25725            1    credit_card
# 1259      1260       78      775         77175            3    credit_card
# 1384      1385       78      867         25725            1           cash
# ...

# %%
df_new = subset_df[subset_df['shop_id']!=78]

# %%
df_new.describe()
# Out:
#           order_id      shop_id      user_id  order_amount  total_items
# count  4937.000000  4937.000000  4937.000000   4937.000000  4937.000000
# mean   2499.551347    49.846465   849.752279    302.580514     1.994734
# std    1444.069407    29.061131    86.840313    160.804912     0.982821
# min       1.000000     1.000000   700.000000     90.000000     1.000000
# 25%    1248.000000    24.000000   775.000000    163.000000     1.000000
# 50%    2497.000000    50.000000   850.000000    284.000000     2.000000
# 75%    3751.000000    74.000000   925.000000    387.000000     3.000000
# max    5000.000000   100.000000   999.000000   1760.000000     8.000000

# %%
plt.scatter(df_new['shop_id'], df_new['order_amount'])

# %%
plt.hist(df_new['order_amount'])
# Out:
# (array([2.088e+03, 1.821e+03, 7.790e+02, 1.840e+02, 4.900e+01, 1.300e+01,
#         0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([  90.,  257.,  424.,  591.,  758.,  925., 1092., 1259., 1426.,
#         1593., 1760.]),
#  <BarContainer object of 10 artists>)

# %%
quant_shop = df_new.groupby('shop_id')['total_items'].sum().sort_values(ascending=False)

# %%
quant_shop
# Out:
# shop_id
# 13    136
# 84    132
# 53    130
# 71    130
# 81    128
#      ...
# 44     71
# 16     71
# 56     69
# 85     67
# 42     63
# Name: total_items, Length: 99, dtype: int64

# %%
df_new[df_new['shop_id']==13]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 105        106       13      746           320            2           cash
# 121        122       13      958           480            3    credit_card
# 210        211       13      701           160            1    credit_card
# 505        506       13      970           480            3           cash
# 584        585       13      906           160            1           cash
# ...        ...      ...      ...           ...          ...            ...
# 4570      4571       13      992           160            1    credit_card
# 4791      4792       13      983           320            2           cash
# 4847      4848       13      993           960            6           cash
# 4953      4954       13      956           320            2           cash
# 4962      4963       13      923           480            3           cash
#
#                   created_at
# 105  2017-03-16 15:04:15.429
# ...

# %%
df_grouped = df_new.groupby('shop_id')['user_id'].nunique().sort_values(ascending=False) #doing additional analysis to evaluate which shop extracts most variety of users

# %%
df_grouped
# Out:
# shop_id
# 71    62
# 19    60
# 53    60
# 70    56
# 89    56
#       ..
# 56    34
# 44    34
# 38    34
# 85    34
# 42    30
# Name: user_id, Length: 99, dtype: int64

# %%
df_new[df_new['shop_id']==71].groupby('shop_id')['order_amount'].mean()
# Out:
# shop_id
# 71    323.030303
# Name: order_amount, dtype: float64

# %%
#end of analysis
